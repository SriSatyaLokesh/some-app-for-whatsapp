# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()

# %%
i=0
with open("WhatsApp Chat with CSE 2K16-2K20.txt","r") as f:
  for line in f:
    print(line)
    i+=1
    if i==15:
      break

[
 {
     "datetime": "11/05/2019, 2:40 pm",
      "isAction":true,
      "action": "Siddhu😎 created group CSE 2K16-2K20"
 },
 {
     "datetime":"12/10/2019, 11:21 am",
     "isMessage":"+91 81432 75536",
     "message": "Remainder",
 },
 {
     "datetime":"25/10/2019, 3:30 pm"
    "user":"+91 81432 75536", 
    "isMedia":true     
 }
]
# Out:
# 11/05/2019, 2:40 pm - Siddhu😎 created group "CSE 2K16-2K20"
#
# 11/05/2019, 2:40 pm - You were added
#
# 10/10/2019, 11:13 am - Vineel@cseA left
#
# 10/10/2019, 11:49 am - +91 70950 90015 changed to +91 80746 33539
#
# 11/10/2019, 7:48 am - Vineel@cseA joined using this group's invite link
#
# 12/10/2019, 11:21 am - +91 81432 75536: Remainder
#
# 12/10/2019, 1:55 pm - +91 97044 13836: <Media omitted>
#
# 12/10/2019, 1:55 pm - +91 97044 13836: <Media omitted>
#
# 12/10/2019, 1:55 pm - +91 97044 13836: Wipro papers
#
# 12/10/2019, 3:25 pm - Karishma@cseD: Thank you sir..
#
# 13/10/2019, 3:20 pm - +91 70369 04545: This message was deleted
#
# 13/10/2019, 3:22 pm - +91 93814 67707: This message was deleted
#
# 25/10/2019, 3:30 pm - +91 81432 75536: <Media omitted>
#
# 25/10/2019, 3:30 pm - +91 81432 75536: <Media omitted>
#
# 25/10/2019, 3:33 pm - +91 81432 75536: Dear students these are shortlisted candidates for Hitachi consulting for next rounds

# %%
from datetime import datetime
import json
def isDateObject(s):
  
  try:
    date_time = datetime.strptime(s, "%d/%m/%Y, %I:%M %p")
    # print(date_time)
    return True
  except:
    return False
chat=[]
import re #regEx
k = 0
with open("WhatsApp Chat with CSE 2K16-2K20.txt","r") as f:
  for line in f:
    
    s = line.split(" - ")
    # print(s)
    if len(s)>0:
      if isDateObject(s[0]):
        message = dict()
        message["datetime"] = s[0]
        k+=1
        user_msg = line.replace(s[0]+" - ","").split(": ")
        user = user_msg[0]
        actions = ["added", "changed" , "removed", "joined","left","created"]
        for i in actions:
          if i in user:
            message["isAction"] = True
            message["action"] = user
            break
        if "isAction" not in message:
            message["user"] = user
            if "<Media omitted>" in user_msg[1]:
              message["isMedia"] = True
            else:
              message["isMessage"]= True
              message["message"] = user_msg[1]
        chat.append(message)
        
      else:
        try:
          l = len(chat) - 1
          chat[l]["message"] = chat[l]["message"]+line
        except Exception as err:
          # print(chat[len(chat)-1])
          print(err)
          print(chat[l])
          print(line)
    
# print(chat) 
chat_json = dict()    
for i in range(len(chat)):
  chat_json[str(i)] = chat[i]

chat_json = json.dumps(chat_json)
print(chat_json)
# Out:
# {"0": {"datetime": "11/05/2019, 2:40 pm", "isAction": true, "action": "Siddhu\ud83d\ude0e created group \"CSE 2K16-2K20\"\n"}, "1": {"datetime": "11/05/2019, 2:40 pm", "isAction": true, "action": "You were added\n"}, "2": {"datetime": "10/10/2019, 11:13 am", "isAction": true, "action": "Vineel@cseA left\n"}, "3": {"datetime": "10/10/2019, 11:49 am", "isAction": true, "action": "+91\u00a070950\u00a090015 changed to +91\u00a080746\u00a033539\n"}, "4": {"datetime": "11/10/2019, 7:48 am", "isAction": true, "action": "Vineel@cseA joined using this group's invite link\n"}, "5": {"datetime": "12/10/2019, 11:21 am", "user": "+91 81432 75536", "isMessage": true, "message": "Remainder\n"}, "6": {"datetime": "12/10/2019, 1:55 pm", "user": "+91 97044 13836", "isMedia": true}, "7": {"datetime": "12/10/2019, 1:55 pm", "user": "+91 97044 13836", "isMedia": true}, "8": {"datetime": "12/10/2019, 1:55 pm", "user": "+91 97044 13836", "isMessage": true, "message": "Wipro papers\n"}, "9": {"datetime": "12/10/2019, 3:25 pm", "user": "Karishma@cseD", "isMessage": true, "message": "Thank you sir..\n"}, "10": {"datetime": "13/10/2019, 3:20 pm", "user": "+91 70369 04545", "isMessage": true, "message": "This message was deleted\n"}, "11": {"datetime": "13/10/2019, 3:22 pm", "user": "+91 93814 67707", "isMessage": true, "message": "This message was deleted\n"}, "12": {"datetime": "25/10/2019, 3:30 pm", "user": "+91 81432 75536", "isMedia": true}, "13": {"datetime": "25/10/2019, 3:30 pm", "user": "+91 81432 75536", "isMedia": true}, "14": {"datetime": "25/10/2019, 3:33 pm", "user": "+91 81432 75536", "isMessage": true, "message": "Dear students these are shortlisted candidates for Hitachi consulting for next rounds\n"}, "15": {"datetime": "25/10/2019, 3:38 pm", "user": "+91 81432 75536", "isMessage": true, "message": "The shortlisted students for Hitachi consulting are suppose to fill above document and carry the filled document to further rounds.\n"}, "16": {"datetime": "25/10/2019, 3:56 pm", "user": "+91 81432 75536", "isMedia": true}, "17": {"datetime": "31/10/2019, 5:28 pm", "user": "+91 81432 75536", "isMedia": true}, "18": {"datetime": "31/10/2019, 5:28 pm", "user": "+91 81432 75536", "isMessage": true, "message": "Dear students those names are mentioned in the above list immediately upload your offer letter's or LOI to given below link \n\nFind the below link: https://forms.gle/BQzJi4vTPUXEC8qS6\n*It is not mandatory for students who are Non Placed & already placed but not get offer letter.\n\nThanking you \nPAT office\n"}, "19": {"datetime": "31/10/2019, 5:49 pm", "user": "+91 81432 75536", "isMessage": true, "message": "Those who got Capgemini LOI (Letter Of Intent) upload it on above link.\n"}, "20": {"datetime": "31/10/2019, 6:44 pm", "isAction": true, "action": "+91 81432 75536 added +91 99486 84658\n"}, "21": {"datetime": "01/11/2019, 12:15 pm", "user": "+91 81432 75536", "isMessage": true, "message": "ADDRESS :\nHITACHI  Further process on 6th November, Monday at KMIT campus. (3-5-1026, Narayanguda Rd, Hari Vihar Colony, Bhawani Nagar, Narayanguda, Hyderabad) \nThey will start by 9.00 AM with pre-placement talk followed by GD and TECH and HR interviews.\nPrerequisites:\n1.      Students are required to carry a copy of their resume with a passport size photograph.\n2.      Please print and have the students fill the attached application form prior to the process starts.\n\nPlease have the students reach the venue by 8.00 AM so that they can fill the application form prior and settle by the time we start.\n"}, "22": {"datetime": "01/11/2019, 3:06 pm", "user": "+91 88013 66964", "isMessage": true, "message": "Monday?\n"}, "23": {"datetime": "01/11/2019, 3:14 pm", "user": "+91 81432 75536", "isMessage": true, "message": "Sorry it's Wednesday\n"}, "24": {"datetime": "01/11/2019, 3:31 pm", "user": "Sriram Ambrla@cseD", "isMessage": true, "message": "K sir\n"}, "25": {"datetime": "12/11/2019, 5:40 pm", "user": "+91 81432 75536", "isMedia": true}, " ...

# %%
data = pd.read_json(chat_json)
data = data.transpose()
data
# Out:
#                  datetime  ... isMedia
# 0     11/05/2019, 2:40 pm  ...     NaN
# 1     11/05/2019, 2:40 pm  ...     NaN
# 2    10/10/2019, 11:13 am  ...     NaN
# 3    10/10/2019, 11:49 am  ...     NaN
# 4     11/10/2019, 7:48 am  ...     NaN
# ..                    ...  ...     ...
# 361   23/04/2020, 5:57 pm  ...     NaN
# 362   23/04/2020, 6:01 pm  ...     NaN
# 363   23/04/2020, 6:01 pm  ...    True
# 364   23/04/2020, 6:09 pm  ...     NaN
# 365   25/04/2020, 6:37 am  ...     NaN
#
# [366 rows x 7 columns]
