# %% [markdown]
# <a href="https://colab.research.google.com/github/SriSatyaLokesh/some-app-for-whatsapp/blob/master/notebooks/UI/WhatsAppTxtToJSON-satya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()

# %%
i=0
with open("WhatsApp Chat with CSE 2K16-2K20.txt","r") as f:
  for line in f:
    print(line)
    i+=1
    if i==15:
      break

[
 {
     "datetime": "11/05/2019, 2:40 pm",
      "isAction":true,
      "action": "Siddhu😎 created group CSE 2K16-2K20"
 },
 {
     "datetime":"12/10/2019, 11:21 am",
     "isMessage":"+91 81432 75536",
     "message": "Remainder",
 },
 {
     "datetime":"25/10/2019, 3:30 pm"
    "user":"+91 81432 75536", 
    "isMedia":true     
 }
]
# Out:
# 11/05/2019, 2:40 pm - Siddhu😎 created group "CSE 2K16-2K20"
#
# 11/05/2019, 2:40 pm - You were added
#
# 10/10/2019, 11:13 am - Vineel@cseA left
#
# 10/10/2019, 11:49 am - +91 70950 90015 changed to +91 80746 33539
#
# 11/10/2019, 7:48 am - Vineel@cseA joined using this group's invite link
#
# 12/10/2019, 11:21 am - +91 81432 75536: Remainder
#
# 12/10/2019, 1:55 pm - +91 97044 13836: <Media omitted>
#
# 12/10/2019, 1:55 pm - +91 97044 13836: <Media omitted>
#
# 12/10/2019, 1:55 pm - +91 97044 13836: Wipro papers
#
# 12/10/2019, 3:25 pm - Karishma@cseD: Thank you sir..
#
# 13/10/2019, 3:20 pm - +91 70369 04545: This message was deleted
#
# 13/10/2019, 3:22 pm - +91 93814 67707: This message was deleted
#
# 25/10/2019, 3:30 pm - +91 81432 75536: <Media omitted>
#
# 25/10/2019, 3:30 pm - +91 81432 75536: <Media omitted>
#
# 25/10/2019, 3:33 pm - +91 81432 75536: Dear students these are shortlisted candidates for Hitachi consulting for next rounds

# %%
from datetime import datetime
import json
def isDateObject(s):
  
  try:
    date_time = datetime.strptime(s, "%d/%m/%Y, %I:%M %p")
    # print(date_time)
    return True
  except:
    return False
chat=[]
import re #regEx
k = 0
with open("WhatsApp Chat with CSE 2K16-2K20.txt","r") as f:
  for line in f:
    
    s = line.split(" - ")
    # print(s)
    if len(s)>0:
      if isDateObject(s[0]):
        message = dict()
        message["datetime"] = s[0]
        k+=1
        user_msg = line.replace(s[0]+" - ","").split(": ")
        user = user_msg[0]
        actions = ["added", "changed" , "removed", "joined","left","created"]
        for i in actions:
          if i in user:
            message["isAction"] = True
            message["action"] = user
            break
        if "isAction" not in message:
            message["user"] = user
            if "<Media omitted>" in user_msg[1]:
              message["isMedia"] = True
            else:
              message["isMessage"]= True
              message["message"] = user_msg[1]
        chat.append(message)
        
      else:
        try:
          l = len(chat) - 1
          chat[l]["message"] = chat[l]["message"]+line
        except Exception as err:
          # print(chat[len(chat)-1])
          print(err)
          print(chat[l])
          print(line)
    
# print(chat) 
chat_json = dict()    
for i in range(len(chat)):
  chat_json[str(i)] = chat[i]

chat_json = json.dumps(chat_json)
print(chat_json)

# %%
data = pd.read_json(chat_json)
data = data.transpose()
data
# Out:
#                  datetime  ... isMedia
# 0     11/05/2019, 2:40 pm  ...     NaN
# 1     11/05/2019, 2:40 pm  ...     NaN
# 2    10/10/2019, 11:13 am  ...     NaN
# 3    10/10/2019, 11:49 am  ...     NaN
# 4     11/10/2019, 7:48 am  ...     NaN
# ..                    ...  ...     ...
# 361   23/04/2020, 5:57 pm  ...     NaN
# 362   23/04/2020, 6:01 pm  ...     NaN
# 363   23/04/2020, 6:01 pm  ...    True
# 364   23/04/2020, 6:09 pm  ...     NaN
# 365   25/04/2020, 6:37 am  ...     NaN
#
# [366 rows x 7 columns]
